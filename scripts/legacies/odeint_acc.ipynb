# %% [markdown]
# # Time evolution of $\mathrm{Yb}$ spin-orbit coupled system with 2-body loss

# %% [markdown]
# - Units
#     - $\hbar=1.0545\times 10^{-34} \,\mathrm{J}\cdot\mathrm{s}$
#     - $E_r/\hbar = 8.8593 \,\mathrm{kHz}$
#     - $k_r = \sin\left(\frac{\theta}{2}\right)\frac{2\pi}{556 \,\mathrm{nm}} = 6.9462\times10^6 \, \mathrm{m}^{-1}$
#
# Where $\theta=75.854^\circ$
#
# - Derived Units
#     - $t_r = \hbar/E_r = 0.1129 \,\mathrm{ms}$
#     - $m_r = \hbar^2 k_r^2 / 2 E_r = m_{\mathrm{Yb}} = 2.872×10^{-25} \, \mathrm{kg}$
#
# - Hamiltonian
#
# $$
# \begin{equation}
#     H=\sum_{\mathbf{k}}
#     \begin{pmatrix}
#         c_{\uparrow}^\dagger(\mathbf{k}) & c_{\downarrow}^\dagger(\mathbf{k})
#     \end{pmatrix}
#     \begin{pmatrix}
#         \frac{\hbar^2(q_x-k_r)^2}{2m_{\mathrm{Yb}}} + \frac{\delta}{2} & \frac{\Omega_R}{2} \\
#         \frac{\Omega_R}{2} & \frac{\hbar^2(q_x+k_r)^2}{2m_{\mathrm{Yb}}}-\frac{\delta}{2}
#     \end{pmatrix}
#     \begin{pmatrix}
#         c_{\uparrow}(\mathbf{k}) \\
#         c_{\downarrow}(\mathbf{k})
#     \end{pmatrix}
#     -\frac{1}{N}\frac{i}{2}\gamma\sum_{\mathbf{k}, \mathbf{k}', \mathbf{q}}c_\downarrow^\dagger(\mathbf{k}'+\mathbf{q})c_\uparrow^\dagger(\mathbf{k}-\mathbf{q})c_\uparrow(\mathbf{k})c_\downarrow(\mathbf{k}')
# \end{equation}
# $$
#
# $q_x=[-2.5 k_r, ..., -0.5 k_r, 0, 0.5 k_r, k_r, ..., 3 k_r]$ for $L=12$
#
# - parameters
#   - $\hbar/\hbar = 1$
#   - $k_r/k_r = 1$
#   - $m_{\mathrm{Yb}}/m_r = 1$
#   - $\delta/E_r = 4$
#   - $\Omega_R/E_r = 3.5$
#   - $\gamma/E_r \sim 0.2$
#
#
# - basis
#
# $$\mathcal{B}= \{c_{\sigma_1}^\dagger(\mathbf{k}_1)c_{\sigma_2}^\dagger(\mathbf{k}_2)\cdots c_{\sigma_n}^\dagger(\mathbf{k}_n)\ket{0}:\sigma_j=\uparrow,\downarrow, i_{\mathbf{k}_1}<i_{\mathbf{k}_2}<\cdots<i_{\mathbf{k}_n}\}$$
# $$[H]_{\mathcal{B}}$$

# %%
import os
import time
import itertools
import functools
import operator
import pickle
from pprint import pprint

import jax
jax.config.update("jax_enable_x64", True)
jax.config.update('jax_platform_name', 'cpu')
import jax.numpy as jnp


import numpy as np
import tqdm
import matplotlib.pyplot as plt

import diffrax as dfx

from ybsoc import *

# %%
L = 12
N = 4

hbar = 1.

m_Yb = 1.

q = 1.
delta = 1.5486
omega_R = 1.0585

gamma = 0.1

system = YbSOC2bodyLoss(
    d=2 * (2 * jnp.pi) / L,
    lengths=[L,],
    n_particle=N,
    hbar=hbar,
    q=q,
    m_Yb=m_Yb,
    delta=delta,
    omega_R=omega_R,
    gamma=gamma,
    array_type='numpy'
)

hamiltonian = system.dense_hamiltonian(
    display_progress=True
)
# Out:
# 100%|██████████| 10626/10626 [00:00<00:00, 13112.53it/s]
# 100%|██████████| 10626/10626 [00:02<00:00, 3675.37it/s]

# %%
eigenvalues, eigenvectors = np.linalg.eig(hamiltonian)

# %%
pure = system.get_momentum_eigenstate(
    (
        ((0,), 1),
        ((1,), 1),
        ((2,), 1),
        ((11,), 1),
    )
)

mixture = system.get_momentum_eigenstate(
    (
        ((0,), 1),
        ((1,), -1),
        ((2,), 1),
        ((3,), -1),
    )
)

theta = 1.23096 # p(up) = 2/3, p(down) = 1/3
phi = 0
c = (np.cos(theta / 2), np.exp(1j * phi) * np.sin(theta / 2))

superposition = np.zeros_like(mixture)
for c1, c2, c3, c4 in itertools.product([0, 1], repeat=4):
    amp = c[c1] * c[c2] * c[c3] * c[c4]
    basis = system.get_momentum_eigenstate(
        (
            ((0,), 2 * c1 - 1),
            ((1,), 2 * c2 - 1),
            ((2,), 2 * c3 - 1),
            ((3,), 2 * c4 - 1),
        )
    )
#     superposition = superposition + amp * basis

# %%
# initial_state = pure
initial_state = mixture
# initial_state = superposition

psi_tilde = np.linalg.solve(eigenvectors, initial_state)

t0 = 0
t1 = 0.05 / 0.1129
save_at = np.linspace(t0, t1, 21)
step_size = save_at[1] - save_at[0]

evolution_operator_diag = np.exp(-1j * eigenvalues * step_size / system.hbar)
psis = np.zeros((len(save_at), len(psi_tilde)), dtype=np.complex128)

psis[0, :] = np.einsum('ij,j->i', eigenvectors, psi_tilde)
for i in tqdm.trange(len(save_at)):
    psis[i, :] = np.einsum('ij,j->i', eigenvectors, psi_tilde)
    psi_tilde = evolution_operator_diag * psi_tilde

spin_up_numbers, spin_down_numbers = system.momentum_sp_expected_numbers_vectorized(psis)
# Out:
# 100%|██████████| 21/21 [00:04<00:00,  4.78it/s]

# %%
hamiltonian_jarr = jnp.array(hamiltonian, dtype=jnp.complex128)
initial_rho = jnp.outer(initial_state, initial_state.conj())

def drhodt(t, rho, args):
    (lamb,) = args
    se_term = (-1j / hbar) * (jnp.matmul(hamiltonian_jarr, rho) - jnp.matmul(rho, hamiltonian_jarr.T.conj()))
    decoherence_term = -lamb * (rho - jnp.diag(jnp.diag(rho)))
    return se_term + decoherence_term

term = dfx.ODETerm(drhodt)
solver = dfx.Dopri8()
saveat = dfx.SaveAt(ts=save_at)
stepsize_controller = dfx.PIDController(atol=1e-5, rtol=1e-5)


sol = dfx.diffeqsolve(
    term, solver, t0, t1, 1e-2, initial_rho, (0,),
    stepsize_controller=stepsize_controller, max_steps=4096
)


# sol = dfx.diffeqsolve(
#     term, solver, t0, t1, 1e-2, initial_rho, (0,),
#     saveat=saveat, stepsize_controller=stepsize_controller, max_steps=4096
# )


# dt0 = 0.01
# rho0 = initial_rho
# args = (0,)
# solver_state = None
# controller_state = None
# for i in tqdm.trange(start=1, stop=len(save_at)):
#     dt = save_at[i] - save_at[i - 1]
#     sol = dfx.diffeqsolve(term, solver, save_at[i - 1], save_at[i], dt0,
#                           rho0, args, stepsize_controller=stepsize_controller,
#                           solver_state=solver_state, controller_state=controller_state)
#     solver_state = sol.solver_state
#     controller_state = sol.controller_state
    
    
# rhos = sol.ys
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 hamiltonian_jarr = jnp.array(hamiltonian, dtype=jnp.complex128)
#       2 initial_rho = jnp.outer(initial_state, initial_state.conj())
#       4 def drhodt(t, rho, args):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\numpy\lax_numpy.py:5555, in array(object, dtype, copy, order, ndmin, device)
#    5553 else:
#    5554   raise TypeError(f"Unexpected input type for array: {type(object)}")
# -> 5555 out_array: Array = lax_internal._convert_element_type(
#    5556     out, dtype, weak_type=weak_type, sharding=sharding)
#    5557 if ndmin > np.ndim(out_array):
#    5558   out_array = lax.expand_dims(out_array, range(ndmin - np.ndim(out_array)))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\lax\lax.py:1614, in _convert_element_type(operand, new_dtype, weak_type, sharding, warn_on_complex_to_real_cast)
#    1612   return operand
#    1613 else:
# -> 1614   return convert_element_type_p.bind(
#    1615       operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#    1616       sharding=sharding)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\core.py:502, in Primitive.bind(self, *args, **params)
#     500 def bind(self, *args, **params):
#     501   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 502   return self._true_bind(*args, **params)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\core.py:520, in Primitive._true_bind(self, *args, **params)
#     518 trace_ctx.set_trace(eval_trace)
#     519 try:
# --> 520   return self.bind_with_trace(prev_trace, args, params)
#     521 finally:
#     522   trace_ctx.set_trace(prev_trace)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\lax\lax.py:4701, in _convert_element_type_bind_with_trace(trace, args, params)
#    4699 def _convert_element_type_bind_with_trace(trace, args, params):
#    4700   sharding = params['sharding']
# -> 4701   operand = core.Primitive.bind_with_trace(convert_element_type_p, trace, args, params)
#    4702   if sharding is not None and sharding._is_concrete:
#    4703     with core.set_current_trace(trace):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\core.py:525, in Primitive.bind_with_trace(self, trace, args, params)
#     524 def bind_with_trace(self, trace, args, params):
# --> 525   return trace.process_primitive(self, args, params)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\core.py:1029, in EvalTrace.process_primitive(self, primitive, args, params)
#    1027       return primitive.bind_with_trace(arg._trace, args, params)
#    1028 check_eval_args(args)
# -> 1029 return primitive.impl(*args, **params)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\jax\_src\dispatch.py:88, in apply_primitive(prim, *args, **params)
#      86 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      87 try:
# ---> 88   outs = fun(*args)
#      89 finally:
#      90   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
# ValueError: RESOURCE_EXHAUSTED: Out of memory allocating 1806590016 bytes.

# %%
num_op_diag = jnp.array(system.momentum_sp_num_op_diags())

def numper_expectation(rho):
    expected_numbers = jnp.einsum('ij,jj->i', num_op_diag, rho)
    up_total = jnp.sum(expected_numbers[0::2]).item().real
    down_total = jnp.sum(expected_numbers[1::2]).item().real
    return up_total, down_total

total_up_odeint = np.zeros((save_at.size,))
total_down_odeint = np.zeros((save_at.size,))

for i in range(save_at.size):
    total_up_odeint[i], total_down_odeint[i] = numper_expectation(rhos[i])

total_up_odeint /= system.n_particle
total_down_odeint /= system.n_particle

# %%
plt.figure(figsize=(6, 5))
t = save_at * 0.1129

# for i in range(8):
#     plt.plot(t, spin_up_numbers[:, i], label=f"$\\uparrow$, {i}")
#     plt.plot(t, spin_down_numbers[:, i], label=f"$\\downarrow$, {i}")

total_up = jnp.sum(spin_up_numbers, axis=1) / system.n_particle
total_down = jnp.sum(spin_down_numbers, axis=1) / system.n_particle

plt.plot(t, total_up, label="$\\uparrow$")
plt.plot(t, total_down, label="$\\downarrow$")
plt.plot(t, total_up + total_down, label="$\\uparrow + \\downarrow$")

plt.ylabel("$\\langle n \\rangle$")
plt.xlabel("$t (ms)$")

plt.legend()
plt.show()

# %%
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(6, 15))

    ax1.plot(t, total_up,   label="$Exact$")
    ax1.plot(t, total_up_odeint, label="$ODEInt$")
    ax1.set_ylabel("$\\langle n_{\\uparrow} \\rangle$")
    ax1.legend()

    ax2.plot(t, total_down,   label="$Exact$")
    ax2.plot(t, total_down_odeint, label="$ODEInt$")
    ax2.set_ylabel("$\\langle n_{\\downarrow} \\rangle$")
    ax2.legend()


    ax3.plot(t, total_up + total_down, label="$Exact$")
    ax3.plot(t, total_up_odeint + total_down_odeint, label="$ODEInt$")
    ax3.set_ylabel("$\\langle n_{\\uparrow} \\rangle + \\langle n_{\\downarrow} \\rangle$")
    ax3.legend()


    ax3.set_xlabel("$t\\,(ms)$")



    # 레이아웃 자동 조정
    plt.tight_layout()
    plt.show()

# %%
np.max(np.abs(total_down - total_down_odeint)) / np.max(np.abs(total_down))
# Out:
# np.float64(1.5641307582470206e-08)

# %%
from matplotlib.animation import FFMpegWriter

def make_video(t, up_nums, down_nums, output_path, fps=60):
    """
    a_data, b_data: shape = (num_frames, N)
                    시간축으로 변화하는 a, b 데이터
    output_path: 출력할 mp4 경로
    fps: 초당 프레임 수
    """
    num_frames = len(t)
    N = up_nums.shape[1]

    # x축 index
    index = np.arange(N)
    # 막대 너비
    width = ((6 - 1) / N) * 0.75 / 2

    # ---------- (1) 초기 그래프 설정 ----------
    # 첫 프레임(0) 기준으로 막대그래프를 그려두고, 참조를 저장해 놓습니다.
    up_num = up_nums[0]
    down_num = down_nums[0]
    total_num = up_num + down_num

    fig, ax = plt.subplots(figsize=(6, 4))

    # 배경(a+b) 막대: alpha=0.2, color='green', 너비=2*width
    bar_total = ax.bar(index, total_num, width=2*width, alpha=0.2, color='green')

    # a, b 막대: grouped bar
    bar_up = ax.bar(index - width/2, up_num, width, label='up')
    bar_down = ax.bar(index + width/2, down_num, width, label='down')

    ax.set_xticks(index)
    ax.set_xlabel('Index')
    ax.set_ylabel('$\\langle n\\rangle$')
    ax.set_title('t=0.00')
    ax.legend()

    # ---------- (2) 프레임 업데이트 함수 정의 ----------
    def update(frame):
        # 해당 frame에서의 a, b
        up_num = up_nums[frame]
        down_num = down_nums[frame]
        total_num = up_num + down_num

        # 배경(a+b) 막대 높이 갱신
        for rect, h in zip(bar_total, total_num):
            rect.set_height(h)

        # a 막대 높이 갱신
        for rect, h in zip(bar_up, up_num):
            rect.set_height(h)

        # b 막대 높이 갱신
        for rect, h in zip(bar_down, down_num):
            rect.set_height(h)

        # 예: 프레임 번호 혹은 시간에 따라 타이틀 갱신
        ax.set_title(f't={t[frame]:.2f} ms')

    # ---------- (3) mp4로 저장 ----------
    writer = FFMpegWriter(fps=fps, metadata=dict(artist='Me'), bitrate=1800)
    with writer.saving(fig, output_path, dpi=100):
        # 전체 프레임 순회하며 그린 뒤 저장
        for frame in tqdm.trange(num_frames, desc="making video"):
            update(frame)
            writer.grab_frame()

    plt.close(fig)

# %%
from IPython.display import Video

video_path = "../visualizations/output.mp4"

make_video(t, spin_up_numbers, spin_down_numbers, video_path)
Video(video_path, embed=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-3555074721> in <cell line: 0>()
#       3 video_path = "../visualizations/output.mp4"
#       4
# ----> 5 make_video(t, spin_up_numbers, spin_down_numbers, video_path)
#       6 Video(video_path, embed=True)
#
# <ipython-input-13-581697970> in make_video(t, up_nums, down_nums, output_path, fps)
#      61     # ---------- (3) mp4로 저장 ----------
#      62     writer = FFMpegWriter(fps=fps, metadata=dict(artist='Me'), bitrate=1800)
# ---> 63     with writer.saving(fig, output_path, dpi=100):
#      64         # 전체 프레임 순회하며 그린 뒤 저장
#      65         for frame in tqdm.trange(num_frames, desc="making video"):
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     219
#     220         # This particular sequence is what contextlib.contextmanager wants
# --> 221         self.setup(fig, outfile, dpi, *args, **kwargs)
#     222         with mpl.rc_context({'savefig.bbox': None}):
#     223             try:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/animation.py in setup(self, fig, outfile, dpi)
#     306     def setup(self, fig, outfile, dpi=None):
#     307         # docstring inherited
# --> 308         super().setup(fig, outfile, dpi=dpi)
#     309         self._w, self._h = self._adjust_frame_size()
#     310         # Run here so that grab_frame() can write the data to a pipe. This
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/animation.py in setup(self, fig, outfile, dpi)
#     166         """
#     167         # Check that path is valid
# --> 168         Path(outfile).parent.resolve(strict=True)
#     169         self.outfile = outfile
#     170         self.fig = fig
#
# /usr/lib/python3.11/pathlib.py in resolve(self, strict)
#     991
#     992         try:
# --> 993             s = os.path.realpath(self, strict=strict)
#     994         except OSError as e:
#     995             check_eloop(e)
#
# /usr/lib/python3.11/posixpath.py in realpath(filename, strict)
#
# /usr/lib/python3.11/posixpath.py in _joinrealpath(path, rest, strict, seen)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../visualizations'
