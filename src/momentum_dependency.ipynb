# %% [markdown]
# # Momentum dependence of loss both non-Hermitian and Lindbladian

# %% [markdown]
# - Lindbladian
# $$\frac{d\rho}{dt}=-\frac{i}{\hbar}[H_\text{free}, \rho] + \sum_p \left(L_p\rho L_p^\dagger - \frac{1}{2}\{L_p^\dagger L_p, \rho\}\right)$$
# $$L_p=\sqrt{\frac{\gamma}{V}}\sum_q c_\uparrow(q-k)c_\downarrow(k)$$
# multiplying $n_\sigma(q)$ to the left
# $$
# \frac{d}{dt}\rho n_\sigma(q_x)=-\frac{i}{\hbar}[H_\text{free}\rho n_\sigma(q_x)-\rho H_\text{free}n_\sigma(q_x)]+\sum_p\left(L_p\rho L_p^\dagger n_\sigma(q_x)-\frac{1}{2}L_p^\dagger L_p\rho n_\sigma(q_x)-\frac{1}{2}\rho L_p^\dagger L_p n_\sigma(q_x)\right)
# $$
# apply trace on both side and rearrange:
# $$
# \frac{d}{dt}\braket{n_\sigma(q_x)}=-\frac{i}{\hbar}\underbrace{\braket{[n_\sigma(q_x), H_\text{free}]}}_{0}+\left\langle\sum_p\left(\frac{1}{2}L_p^\dagger n_\sigma(q_x)L_p-\frac{1}{2} L_p^\dagger L_pn_\sigma(q_x)\right)+\underbrace{\sum_p \left(\frac{1}{2}L_p^\dagger n_\sigma(q_x)L_p-\frac{1}{2} n_\sigma(q_x)L_p^\dagger L_p\right)}_{\text{h.c.}}\right\rangle
# $$
# $$
# \begin{align}
# 	\frac{d}{dt}\braket{n_\sigma(q_x)}&=\frac{1}{2}\sum_p\left\langle L_p^\dagger[n_\sigma(q_x), L_p]\right\rangle+\text{c.c.} \\
# 	&=\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger\left[c_\sigma(q_x)^\dagger c_\sigma(q_x), \sum_{p'}c_\uparrow(p-p')c_\downarrow(p')\right]\right\rangle
# \end{align}
# $$
# for $\sigma=\uparrow$:
# $$
# \begin{align}
# 	\frac{d}{dt}\braket{n_\uparrow(q_x)}&=\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger\sum_{p'}\left[c_\uparrow(q_x)^\dagger c_\uparrow(q_x), c_\uparrow(p-p')\right]c_\downarrow(p')\right\rangle\\
# 	&=-\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger c_\uparrow(q_x)c_\downarrow(p-q_x)\right\rangle\\
# 	&=-\frac{\gamma}{V}\sum_{p,p'}\operatorname{Re}\left(c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p') c_\uparrow(q_x)c_\downarrow(p-q_x)\right\rangle
# \end{align}
# $$
# similarly, for $\sigma=\downarrow$,
# $$
# \begin{align}
# 	\frac{d}{dt}\braket{n_\downarrow(q_x)}&=\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger\sum_{p'}c_\uparrow(p-p')\left[c_\downarrow(q_x)^\dagger c_\downarrow(q_x), c_\downarrow(p')\right]\right\rangle\\
# 	&=-\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger c_\uparrow(p-q_x) c_\downarrow(q_x)\right\rangle\\
# 	&=-\frac{\gamma}{V}\sum_{p,p'}\operatorname{Re}\left(c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p') c_\uparrow(p-q_x) c_\downarrow(q_x)\right\rangle
# \end{align}
# $$
# - Non-Hermitian
# ignore the jump term:
# $$
# \frac{d}{dt}\rho n_\sigma(q_x)=-\frac{i}{\hbar}[H_\text{free}\rho n_\sigma(q_x)-\rho H_\text{free}n_\sigma(q_x)]-\frac{1}{2}\sum_p\left(L_p^\dagger L_p\rho n_\sigma(q_x)+\rho L_p^\dagger L_p n_\sigma(q_x)\right)$$
# take trace, cyclic rearrange
# $$
# \begin{align}
# \frac{d}{dt}\braket{n_\sigma(q_x)}&=-\frac{i}{\hbar}\underbrace{\braket{[n_\sigma(q_x), H_\text{free}]}}_{0}-\frac{1}{2}\sum_p\left(\braket{n_\sigma(q_x)L_p^\dagger L_p}+\braket{L_p^\dagger L_p n_\sigma(q_x)}\right)\\
# &=-\frac{i}{\hbar}\underbrace{\braket{[n_\sigma(q_x), H_\text{free}]}}_{0}-\sum_p\braket{n_\sigma(q_x)L_p^\dagger L_p}\\
# &=-\frac{\gamma}{V}\sum_{p,p_1,p_2}\left\langle{c_\sigma^\dagger(q_x)c_\sigma(q_x)c_\downarrow^\dagger(p_2-p)c_\uparrow^\dagger(p_1+p)}c_\uparrow(p_1)c_\downarrow(p_2)\right\rangle
# \end{align}
# $$
#
# Hence, the short time evolution is governed by:
# - Lindbladian
# $$
# \frac{d\braket{n_\uparrow(q_x)}}{dt} = -\frac{\gamma}{V}\sum_{p, p'} \operatorname{Re}\left\langle c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p')c_\uparrow(q_x)c_\downarrow(p-q_x)\right\rangle
# $$
# $$
# \frac{d\braket{n_\downarrow(q_x)}}{dt} = -\frac{\gamma}{V}\sum_{p, p'} \operatorname{Re}\left\langle c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p')c_\uparrow(p-q_x)c_\downarrow(q_x)\right\rangle
# $$
# $$
# \left.\frac{d}{dt}\braket{n_\uparrow(q_x)}\right|_{t=0} = -\sum_p \left[\operatorname{Re}\left\langle c_\downarrow^\dagger(p)c_\uparrow^\dagger(q_x)c_\uparrow(q_x)c_\downarrow(p) \right\rangle _F + \operatorname{Re}\left\langle c_\downarrow^\dagger(q_x)c_\uparrow^\dagger(p)c_\uparrow(q_x)c_\downarrow(p) \right\rangle _F\right]
# $$
#
#
# - non-Hermitian
# $$
# \frac{d\braket{n_\sigma(q_x)}}{dt} = -\frac{\gamma}{V}\sum_{p,p_1,p_2}\left\langle{c_\sigma^\dagger(q_x)c_\sigma(q_x)c_\downarrow^\dagger(p_2-p)c_\uparrow^\dagger(p_1+p)}c_\uparrow(p_1)c_\downarrow(p_2)\right\rangle
# $$

# %%
import sympy as sp
from sympy.physics.quantum import Dagger, Commutator, AntiCommutator
from sympy.physics.quantum.fermion import FermionOp
from sympy.physics.secondquant import wicks, F, Fd

import numpy as np
import matplotlib.pyplot as plt

import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

from quant_mech import ybsoc

from matplotlib.collections import LineCollection
from matplotlib.colors import LinearSegmentedColormap, Normalize
from matplotlib.cm import ScalarMappable

sp.init_printing(use_latex='mathjax')

# %%
p, q_x = sp.symbols('p q_x')

up = sp.Symbol('\\uparrow')
down = sp.Symbol('\\downarrow')

u = sp.Symbol('u') # upper
l = sp.Symbol('l') # lower

alpha = sp.Function('alpha')
beta = sp.Function('beta')

c_up = lambda mom: F((mom, up))
c_down = lambda mom: F((mom, down))
c_upper = lambda mom: F((mom, u))
c_lower = lambda mom: F((mom, l))


c_up_dag = lambda mom: Fd((mom, up))
c_down_dag = lambda mom: Fd((mom, down))
c_upper_dag = lambda mom: Fd((mom, u))
c_lower_dag = lambda mom: Fd((mom, l))


def transformation_rules(mom):
    return {
        c_up(mom): sp.conjugate(alpha(mom))*c_upper(mom) - sp.conjugate(beta(mom))*c_lower(mom),
        c_up_dag(mom): alpha(mom)*c_upper_dag(mom) - beta(mom)*c_lower_dag(mom),
        c_down(mom): sp.conjugate(beta(mom))*c_upper(mom) + sp.conjugate(alpha(mom))*c_lower(mom),
        c_down_dag(mom): beta(mom)*c_upper_dag(mom) + alpha(mom)*c_lower_dag(mom),
    }

# %%
# expr = c_down_dag(p)*c_up_dag(q_x)*c_up(q_x)*c_down(p)
# expr += c_down_dag(q_x)*c_up_dag(p)*c_up(q_x)*c_down(p)


expr = c_down_dag(p)*c_up_dag(q_x)*c_up(q_x)*c_down(p)
# expr = c_down_dag(q_x)*c_up_dag(p)*c_up(q_x)*c_down(p)
expr
# Out:
# f+((p, \downarrow))⋅f+((q_x, \uparrow))⋅f((q_x, \uparrow))⋅f((p, \downarrow))

# %%
rules = transformation_rules(p) | transformation_rules(q_x)
expr_transformed = expr.subs(rules)
expr_transformed
# Out:
#                                                                                ↪
# (α(p)⋅f+((p, l)) + β(p)⋅f+((p, u)))⋅(α(qₓ)⋅f+((q_x, u)) - β(qₓ)⋅f+((q_x, l)))⋅ ↪
#
# ↪ ⎛_____               _____            ⎞ ⎛____             ____          ⎞
# ↪ ⎝α(qₓ)⋅f((q_x, u)) - β(qₓ)⋅f((q_x, l))⎠⋅⎝α(p)⋅f((p, l)) + β(p)⋅f((p, u))⎠

# %%
expr_expanded = sp.expand(expr_transformed)
sp.latex(expr_expanded)
# Out:
# '\\alpha{\\left(p \\right)} \\alpha{\\left(q_{x} \\right)} \\overline{\\alpha{\\left(p \\right)}} \\overline{\\alpha{\\left(q_{x} \\right)}} {a^\\dagger_{\\left( p, \\  l\\right)}} {a^\\dagger_{\\left( q_{x}, \\  u\\right)}} a_{\\left( q_{x}, \\  u\\right)} a_{\\left( p, \\  l\\right)} - \\alpha{\\left(p \\right)} \\alpha{\\left(q_{x} \\right)} \\overline{\\alpha{\\left(p \\right)}} \\overline{\\beta{\\left(q_{x} \\right)}} {a^\\dagger_{\\left( p, \\  l\\right)}} {a^\\dagger_{\\left( q_{x}, \\  u\\right)}} a_{\\left( q_{x}, \\  l\\right)} a_{\\left( p, \\  l\\right)} + \\alpha{\\left(p \\right)} \\alpha{\\left(q_{x} \\right)} \\overline{\\alpha{\\left(q_{x} \\right)}} \\overline{\\beta{\\left(p \\right)}} {a^\\dagger_{\\left( p, \\  l\\right)}} {a^\\dagger_{\\left( q_{x}, \\  u\\right)}} a_{\\left( q_{x}, \\  u\\right)} a_{\\left( p, \\  u\\right)} - \\alpha{\\left(p \\right)} \\alpha{\\left(q_{x} \\right)} \\overline{\\beta{\\left(p \\right)}} \\overline{\\beta{\\left(q_{x} \\right)
# ...

# %%
# wicks(expr_expanded, keep_only_fully_contracted=True, simplify=True)

# %%
t_unit = 0.1129 # ms
E_unit = 9.3428e-31 # J  recoil energy
T_unit = 6.7669e-2 # μK

# %%
hbar = 1.0
k_r = 1.0
m_Yb = 1.0
delta = 4.0
omega_R = 3.5
gamma = 0.5
temperature = 0.4 / T_unit
mu = 4.8

fermi_level = 4.8

# %%
zerotemp = temperature < 1e-12

# %%
m = 100
q_left = -8
q_right = 6
points_to_calc = np.linspace(q_left, q_right, (q_right - q_left) * m + 1)
int_momentums = np.linspace(q_left * m, q_right * m, (q_right - q_left) * m + 1, dtype=np.int64)
zero_idx = np.argmin(np.abs(points_to_calc))

k0 = points_to_calc[1] - points_to_calc[0]
L = 2 * np.pi / k0

energies = np.stack([
    ybsoc.e2(points_to_calc, m_Yb, k_r, delta, omega_R, hbar),
    ybsoc.e1(points_to_calc, m_Yb, k_r, delta, omega_R, hbar)
])
above_fermi = energies > fermi_level
below_fermi = energies <= fermi_level
if zerotemp:
    fermi_dirac = below_fermi.astype(float)
else:
    beta = 1 / temperature
    fermi_dirac = 1 / (np.exp(beta * (energies - mu)) + 1)


thetas = ybsoc.theta(points_to_calc, m_Yb, k_r, delta, omega_R, hbar)
alphas = np.cos(thetas)
betas = np.sin(thetas)

# %%
ticks = [i for i in range(-8, 7)]
tick_labels = []
for q in ticks:
    if q == 0:
        formatted_str = "$0$"
    elif q == 1:
        formatted_str = "$k_r$"
    elif q == -1:
        formatted_str = "$-k_r$"
    else:
        if q == int(q):
            num_str = str(int(q))
        else:
            num_str = str(q)
        formatted_str = f"${num_str}k_r$"
    tick_labels.append(formatted_str)

# %%
qs_dense = np.linspace(-8, 6, 1401)

E_upper_dense = ybsoc.e1(qs_dense, m_Yb, k_r, delta, omega_R, hbar)
E_lower_dense = ybsoc.e2(qs_dense, m_Yb, k_r, delta, omega_R, hbar)

thetas_dense = ybsoc.theta(
    qs_dense,
    delta=delta,
    omega_R=omega_R,
    k_r=k_r,
    m_Yb=m_Yb,
)
alphas_dense = np.cos(thetas_dense)
betas_dense = np.sin(thetas_dense)

custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", ['tomato', 'cornflowerblue'])
# custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", ['red', 'blue'])

color_determining_array_up = np.abs(betas_dense)**2
color_determining_array_down = np.abs(alphas_dense)**2

points_up = np.array([qs_dense, E_upper_dense]).T.reshape(-1, 1, 2)
segments_up = np.concatenate([points_up[:-1], points_up[1:]], axis=1)

points_down = np.array([qs_dense, E_lower_dense]).T.reshape(-1, 1, 2)
segments_down = np.concatenate([points_down[:-1], points_down[1:]], axis=1)

norm = Normalize(vmin=0.0, vmax=1.0)
lc_up = LineCollection(segments_up, cmap=custom_cmap, norm=norm)
lc_down = LineCollection(segments_down, cmap=custom_cmap, norm=norm)

lc_up.set_array(color_determining_array_up[:-1])
lc_down.set_array(color_determining_array_down[:-1])
lc_up.set_linewidth(2)
lc_down.set_linewidth(2)

fig, ax = plt.subplots(figsize=(6, 4))

ax.add_collection(lc_up)
ax.add_collection(lc_down)

ax.set_xlim(qs_dense.min(), qs_dense.max())
ax.set_ylim(E_lower_dense.min() - 1, E_upper_dense.max() + 1)

sm = ScalarMappable(cmap=custom_cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ticks=[0, 1], ax=ax)
cbar.set_ticklabels([r'$m_F=5/2$', r'$m_F=3/2$'])
cbar.ax.invert_yaxis()
cbar.set_label(r'Mixing Ratio')
ax.set_xticks(ticks, tick_labels)
ax.set_xlabel("$q_x$")
ax.set_ylabel("$E/E_r$")
ax.grid(True)


if zerotemp:
    q_fermi_sea = np.concatenate([
        points_to_calc[below_fermi[0]],
        points_to_calc[below_fermi[1]]
    ])
    E_fermi_sea = np.concatenate([
        energies[0][below_fermi[0]],
        energies[1][below_fermi[1]]
    ])
    q_rands = 0.1 * np.random.uniform(-1, 1, size=q_fermi_sea.shape)
    e_rands = 1.0 * np.random.uniform(-1, 1, size=E_fermi_sea.shape)

    ax.axhline(y=fermi_level, color='k', linestyle='--', label='fermi_level')
    ax.scatter(q_fermi_sea + q_rands, E_fermi_sea + e_rands, color='blueviolet', s=4, alpha=0.7)
else:
    rands = np.random.uniform(0, 1, size=fermi_dirac.shape)
    selected = rands <= fermi_dirac
    _qq = np.concatenate([
        points_to_calc[selected[0]],
        points_to_calc[selected[1]]
    ])
    _ee = np.concatenate([
        energies[0][selected[0]],
        energies[1][selected[1]]
    ])
    
    
    ax.axhline(y=mu, color='k', linestyle='--', label='$\\mu$')
    ax.scatter(_qq, _ee, color='blueviolet', s=4, alpha=0.7)
    
ax.legend()

# ax.scatter(q_test, E_downs_test, color='red', s=50, edgecolors='k', zorder=5)
# ax.scatter(q_test, E_ups_test, color='blue', s=50, edgecolors='k', zorder=5)

plt.tight_layout()
plt.savefig("band.png", dpi=300, transparent=True)
plt.show()

# %%
class FermionOp:
    def __init__(self, label: str, momentum: int, dagger: bool = False):
        self.label = label        # 0 (lower) or 1 (upper)
        self.momentum = momentum  # integer coefficient of momentum value
        self.dagger = dagger      # creation (True) or annihilation (False)

    def _generate_latex_str(self):
        if self.dagger:
            prefix = f"c_{{{self.label}}}^{{\\dagger}}"
        else:
            prefix = f"c_{{{self.label}}}"
        
        if self.momentum == 0:
            momentum_str = "0"
        elif self.momentum == 1:
            momentum_str = "k_0"
        elif self.momentum == -1:
            momentum_str = "-k_0"
        else:
            momentum_str = f"{self.momentum}k_0"
        
        return f"{prefix}({momentum_str})"

    def __repr__(self):
        return f"FermionOp(label={self.label}, momentum={self.momentum}, dagger={self.dagger})"

    def _repr_latex_(self):
        latex_str = self._generate_latex_str()
        return f"${latex_str}$"
    
    def __mul__(self, other):
        if isinstance(other, FermionOp):
            # op * op -> returns a new string
            return FermionOpString([self, other])
        if isinstance(other, FermionOpString):
            # op * string -> prepends the op to the string
            return FermionOpString([self] + other.ops)
        # For other types, indicate the operation is not implemented
        return NotImplemented
    
class FermionOpString:
    def __init__(self, ops: list[FermionOp]):
        self.ops = ops

    def _generate_latex_str(self):
        return " ".join([op._generate_latex_str() for op in self.ops])

    def __repr__(self):
        return f"FermionOpString(ops={self.ops})"

    def _repr_latex_(self):
        latex_str = self._generate_latex_str()
        return f"${latex_str}$"
    
    def __mul__(self, other):
        if isinstance(other, FermionOp):
            return FermionOpString(self.ops + [other])
        if isinstance(other, FermionOpString):
            return FermionOpString(self.ops + other.ops)
        return NotImplemented

# %%
def int_mom_to_idx(momentum: int) -> int:
    return momentum + zero_idx
    
def _energy(species: int, momentum: int) -> float:
    idx = int_mom_to_idx(momentum)
    if idx < 0 or idx >= len(points_to_calc):
        raise ValueError(f"Momentum index {idx} out of bounds.")
    return energies[species][idx]

def energy(fermion_op: FermionOp) -> float:
    if fermion_op.label == "lower":
        return _energy(0, fermion_op.momentum)
    if fermion_op.label == "upper":
        return _energy(1, fermion_op.momentum)
    raise ValueError("label must be lower or upper.")

def is_creation_type(fermion_op: FermionOp) -> bool:
    above_fermi = energy(fermion_op) > fermi_level
    if above_fermi:
        return fermion_op.dagger
    else:
        return not fermion_op.dagger

def is_annihilation_type(fermion_op: FermionOp) -> bool:
    return not is_creation_type(fermion_op)

# %% [markdown]
# $$\left\langle c_\downarrow^\dagger(q_1)c_\uparrow^\dagger(q_2)c_\uparrow(q_3)c_\downarrow(q_4)\right\rangle$$
# $$q_1 = p-p',\quad q_2=p',\quad q_3=q_x,\quad q_4=p-q_x$$
# or $$q_3=p-q_x,\quad q_4=q_x$$

# %%
def fermi_sea_expectation(fermion_op_string: FermionOpString) -> float:
    ops = fermion_op_string.ops
    n = len(ops)
    
    # Check if the number of operators is even
    if n % 2 != 0:
        return 0.0
    
    creation_types = [op for op in ops if is_creation_type(op)]
    annihilation_types = [op for op in ops if is_annihilation_type(op)]
    
    num_creation_type = len(creation_types)
    num_annihilation_type = len(annihilation_types)
    
    assert num_creation_type + num_annihilation_type == n, "Mismatch in operator classification."
    
    if num_creation_type != num_annihilation_type:
        return 0.0
    
    # Check momentum conservation
    total_momentum = sum(op.momentum if op.dagger else -op.momentum for op in ops)
    if total_momentum != 0:
        return 0.0
    
    # Check if all creation operators correspond to states above the Fermi level
    for op in creation_ops:
        if energy(op) <= fermi_level:
            return 0.0
    
    # Check if all annihilation operators correspond to states below the Fermi level
    for op in annihilation_ops:
        if energy(op) > fermi_level:
            return 0.0
    
    # If all checks passed, return 1.0 (non-zero expectation value)
    return 1.0

# %%
FermionOp(0, -1, True) * FermionOp(0, -1, True)
# Out:
# FermionOpString(ops=[FermionOp(label=0, momentum=-1, dagger=True), FermionOp(label=0, momentum=-1, dagger=True)])

# %%
def _corr(qx, p):
    # q_x, p: integer coefficient of momentum
    qx_idx = qx + zero_idx
    p_idx = p + zero_idx
    
    alpha_qx = alphas[qx_idx]
    alpha_p = alphas[p_idx]
    beta_qx = betas[qx_idx]
    beta_p = betas[p_idx]
    
    n_lower_qx, n_upper_qx = fermi_dirac[:, qx_idx]
    n_lower_p, n_upper_p = fermi_dirac[:, p_idx]
    
    # print(f"{n_lower_qx=}, {n_upper_qx=}")
    # print(f"{n_lower_p=}, {n_upper_p=}")
    
    assert np.isrealobj(alpha_qx)
    assert np.isrealobj(alpha_p)
    assert np.isrealobj(beta_qx)
    assert np.isrealobj(beta_p)

    _1_ = ((alpha_qx *  beta_p) ** 2) * n_upper_qx * n_upper_p \
        + (( beta_qx *  beta_p) ** 2) * n_lower_qx * n_upper_p \
        + ((alpha_qx * alpha_p) ** 2) * n_upper_qx * n_lower_p \
        + (( beta_qx * alpha_p) ** 2) * n_lower_qx * n_lower_p
        
    _2_ = -(beta_qx * alpha_p * alpha_qx * beta_p) * n_upper_qx * n_upper_p \
        + (alpha_qx * alpha_p * beta_qx * beta_p) * n_lower_qx * n_upper_p \
        + (beta_qx * beta_p * alpha_qx * alpha_p) * n_upper_qx * n_lower_p \
        - (alpha_qx * beta_p * beta_qx * alpha_p) * n_lower_qx * n_lower_p

    return _1_ + _2_
    


_corr(-25, 10)
# Out:
# np.float64(0.9912846567644303)

# %%
n_lowers = fermi_dirac[0, :]
n_uppers = fermi_dirac[1, :]

alphas_col = alphas[:, np.newaxis]
betas_col = betas[:, np.newaxis]
n_lowers_col = n_lowers[:, np.newaxis]
n_uppers_col = n_uppers[:, np.newaxis]

mat1 = ((alphas_col *  betas) ** 2) * n_uppers_col * n_uppers \
     + (( betas_col *  betas) ** 2) * n_lowers_col * n_uppers \
     + ((alphas_col * alphas) ** 2) * n_uppers_col * n_lowers \
     + (( betas_col * alphas) ** 2) * n_lowers_col * n_lowers
      
mat2 = -( betas_col * alphas * alphas_col *  betas) * n_uppers_col * n_uppers \
     +  (alphas_col * alphas *  betas_col *  betas) * n_lowers_col * n_uppers \
     +  ( betas_col *  betas * alphas_col * alphas) * n_uppers_col * n_lowers \
     -  (alphas_col *  betas *  betas_col * alphas) * n_lowers_col * n_lowers
      
corr_mat = mat1 + mat2

# %%
initial_ups = (alphas ** 2) * n_uppers + (betas ** 2) * n_lowers
initial_downs = (betas ** 2) * n_uppers + (alphas ** 2) * n_lowers

# -dn/dt
loss_rate_up = (gamma / L) * np.sum(corr_mat, axis=1) # sum over p
loss_rate_down = (gamma / L) * np.sum(corr_mat.T, axis=1) # sum over p

# %%
size = initial_ups.shape[0]
size_canon = size + 2 * m

# %%
points_to_calc_canon = np.linspace(-5, 4, 9 * m + 1)

# %%
initial_ups_canon = np.zeros((size_canon))
initial_ups_canon[:-2 * m] = initial_ups
initial_downs_canon = np.zeros((size_canon))
initial_downs_canon[2 * m:] = initial_downs

# -dn/dt
loss_rate_up_canon = np.zeros((size_canon))
loss_rate_up_canon[:-2 * m] = loss_rate_up
loss_rate_down_canon = np.zeros((size_canon))
loss_rate_down_canon[2 * m:] = loss_rate_down

# %%
plt.plot(points_to_calc, initial_ups, label="$\\uparrow$")
plt.plot(points_to_calc, initial_downs, label="$\\downarrow$")
plt.plot(points_to_calc, initial_ups + initial_downs, label="$\\downarrow$")
plt.legend()
plt.show()

# %%
plt.plot(points_to_calc, loss_rate_up, label="$\\uparrow$")
plt.plot(points_to_calc, loss_rate_down, label="$\\downarrow$")
plt.plot(points_to_calc, loss_rate_up + loss_rate_down, label="$\\downarrow$")
plt.legend()
plt.show()

# %%
plt.plot(points_to_calc_canon, initial_ups_canon, label="$\\uparrow$")
plt.plot(points_to_calc_canon, initial_downs_canon, label="$\\downarrow$")
plt.plot(points_to_calc_canon, initial_ups_canon + initial_downs_canon, label="$\\downarrow$")
plt.legend()
plt.show()

# %%
plt.plot(points_to_calc_canon, loss_rate_up_canon, label="$\\uparrow$")
plt.plot(points_to_calc_canon, loss_rate_down_canon, label="$\\downarrow$")
plt.plot(points_to_calc_canon, loss_rate_up_canon + loss_rate_down_canon, label="$\\downarrow$")
plt.legend()
plt.show()

# %%
initial_slopes = np.zeros_like(above_fermi)

cnt = 0
for qx in int_momentums:
    qx_idx = qx + zero_idx
    for p in int_momentums:
        p_idx = p + zero_idx
        if np.abs(corr_mat[qx_idx, p_idx] - _corr(qx, p)) < 1e-15:
            cnt += 1
np.sqrt(cnt)
# Out:
# np.float64(701.0)
