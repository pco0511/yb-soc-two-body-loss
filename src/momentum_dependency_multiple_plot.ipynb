# %% [markdown]
# - Lindbladian
# $$\frac{d\rho}{dt}=-\frac{i}{\hbar}[H_\text{free}, \rho] + \sum_p \left(L_p\rho L_p^\dagger - \frac{1}{2}\{L_p^\dagger L_p, \rho\}\right)$$
# $$L_p=\sqrt{\frac{\gamma}{V}}\sum_q c_\uparrow(q-k)c_\downarrow(k)$$
# multiplying $n_\sigma(q)$ to the left
# $$
# \frac{d}{dt}\rho n_\sigma(q_x)=-\frac{i}{\hbar}[H_\text{free}\rho n_\sigma(q_x)-\rho H_\text{free}n_\sigma(q_x)]+\sum_p\left(L_p\rho L_p^\dagger n_\sigma(q_x)-\frac{1}{2}L_p^\dagger L_p\rho n_\sigma(q_x)-\frac{1}{2}\rho L_p^\dagger L_p n_\sigma(q_x)\right)
# $$
# apply trace on both side and rearrange:
# $$
# \frac{d}{dt}\braket{n_\sigma(q_x)}=-\frac{i}{\hbar}\underbrace{\braket{[n_\sigma(q_x), H_\text{free}]}}_{0}+\left\langle\sum_p\left(\frac{1}{2}L_p^\dagger n_\sigma(q_x)L_p-\frac{1}{2} L_p^\dagger L_pn_\sigma(q_x)\right)+\underbrace{\sum_p \left(\frac{1}{2}L_p^\dagger n_\sigma(q_x)L_p-\frac{1}{2} n_\sigma(q_x)L_p^\dagger L_p\right)}_{\text{h.c.}}\right\rangle
# $$
# $$
# \begin{align}
# 	\frac{d}{dt}\braket{n_\sigma(q_x)}&=\frac{1}{2}\sum_p\left\langle L_p^\dagger[n_\sigma(q_x), L_p]\right\rangle+\text{c.c.} \\
# 	&=\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger\left[c_\sigma(q_x)^\dagger c_\sigma(q_x), \sum_{p'}c_\uparrow(p-p')c_\downarrow(p')\right]\right\rangle
# \end{align}
# $$
# for $\sigma=\uparrow$:
# $$
# \begin{align}
# 	\frac{d}{dt}\braket{n_\uparrow(q_x)}&=\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger\sum_{p'}\left[c_\uparrow(q_x)^\dagger c_\uparrow(q_x), c_\uparrow(p-p')\right]c_\downarrow(p')\right\rangle\\
# 	&=-\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger c_\uparrow(q_x)c_\downarrow(p-q_x)\right\rangle\\
# 	&=-\frac{\gamma}{V}\sum_{p,p'}\operatorname{Re}\left(c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p') c_\uparrow(q_x)c_\downarrow(p-q_x)\right\rangle
# \end{align}
# $$
# similarly, for $\sigma=\downarrow$,
# $$
# \begin{align}
# 	\frac{d}{dt}\braket{n_\downarrow(q_x)}&=\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger\sum_{p'}c_\uparrow(p-p')\left[c_\downarrow(q_x)^\dagger c_\downarrow(q_x), c_\downarrow(p')\right]\right\rangle\\
# 	&=-\sqrt{\frac{\gamma}{V}}\sum_p\operatorname{Re}\left\langle L_p^\dagger c_\uparrow(p-q_x) c_\downarrow(q_x)\right\rangle\\
# 	&=-\frac{\gamma}{V}\sum_{p,p'}\operatorname{Re}\left(c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p') c_\uparrow(p-q_x) c_\downarrow(q_x)\right\rangle
# \end{align}
# $$
# - Non-Hermitian
# ignore the jump term:
# $$
# \frac{d}{dt}\rho n_\sigma(q_x)=-\frac{i}{\hbar}[H_\text{free}\rho n_\sigma(q_x)-\rho H_\text{free}n_\sigma(q_x)]-\frac{1}{2}\sum_p\left(L_p^\dagger L_p\rho n_\sigma(q_x)+\rho L_p^\dagger L_p n_\sigma(q_x)\right)$$
# take trace, cyclic rearrange
# $$
# \begin{align}
# \frac{d}{dt}\braket{n_\sigma(q_x)}&=-\frac{i}{\hbar}\underbrace{\braket{[n_\sigma(q_x), H_\text{free}]}}_{0}-\frac{1}{2}\sum_p\left(\braket{n_\sigma(q_x)L_p^\dagger L_p}+\braket{L_p^\dagger L_p n_\sigma(q_x)}\right)\\
# &=-\frac{i}{\hbar}\underbrace{\braket{[n_\sigma(q_x), H_\text{free}]}}_{0}-\sum_p\braket{n_\sigma(q_x)L_p^\dagger L_p}\\
# &=-\frac{\gamma}{V}\sum_{p,p_1,p_2}\left\langle{c_\sigma^\dagger(q_x)c_\sigma(q_x)c_\downarrow^\dagger(p_2-p)c_\uparrow^\dagger(p_1+p)}c_\uparrow(p_1)c_\downarrow(p_2)\right\rangle
# \end{align}
# $$
#
# Hence, the short time evolution is governed by:
# - Lindbladian
# $$
# \frac{d\braket{n_\uparrow(q_x)}}{dt} = -\frac{\gamma}{V}\sum_{p, p'} \operatorname{Re}\left\langle c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p')c_\uparrow(q_x)c_\downarrow(p-q_x)\right\rangle
# $$
# $$
# \frac{d\braket{n_\downarrow(q_x)}}{dt} = -\frac{\gamma}{V}\sum_{p, p'} \operatorname{Re}\left\langle c_\downarrow^\dagger(p-p')c_\uparrow^\dagger(p')c_\uparrow(p-q_x)c_\downarrow(q_x)\right\rangle
# $$
# $$
# \left.\frac{d}{dt}\braket{n_\uparrow(q_x)}\right|_{t=0} = -\sum_p \left[\operatorname{Re}\left\langle c_\downarrow^\dagger(p)c_\uparrow^\dagger(q_x)c_\uparrow(q_x)c_\downarrow(p) \right\rangle _F + \operatorname{Re}\left\langle c_\downarrow^\dagger(q_x)c_\uparrow^\dagger(p)c_\uparrow(q_x)c_\downarrow(p) \right\rangle _F\right]
# $$
#
#
# - non-Hermitian
# $$
# \frac{d\braket{n_\sigma(q_x)}}{dt} = -\frac{\gamma}{V}\sum_{p,p_1,p_2}\left\langle{c_\sigma^\dagger(q_x)c_\sigma(q_x)c_\downarrow^\dagger(p_2-p)c_\uparrow^\dagger(p_1+p)}c_\uparrow(p_1)c_\downarrow(p_2)\right\rangle
# $$

# %%
import copy
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import LinearSegmentedColormap, Normalize
from matplotlib.cm import ScalarMappable

from quant_mech import ybsoc

# %%
FIG_ROOT = "/home/cwpark/yb-soc-two-body-loss/data/figs"

# %%
t_unit = 0.1129 # ms
E_unit = 9.3428e-31 # J  recoil energy
T_unit = 6.7669e-2 # μK

# %%
hbar = 1.0
k_r = 1.0
m_Yb = 1.0
delta = 4.0
omega_R = 3.5
gamma = 0.5

# Momentum space grid
m = 50
q_left = -8
q_right = 6
points_to_calc = np.linspace(q_left, q_right, (q_right - q_left) * m + 1)
n_points = len(points_to_calc)
k0 = points_to_calc[1] - points_to_calc[0]
L = 2 * np.pi / k0

points_to_calc_canon = np.linspace(q_left - 1, q_right + 1, (q_right - q_left + 2) * m + 1)

# %% [markdown]
# $$\left\langle c_\downarrow^\dagger(p)c_\uparrow^\dagger(q) c_\uparrow(q)c_\downarrow(p)\right\rangle$$

# %%
def corrmat_4_0(alphas: np.ndarray, betas: np.ndarray, n_upper: np.ndarray, n_lower: np.ndarray):
    assert alphas.shape == betas.shape == n_upper.shape == n_lower.shape
    assert np.isrealobj(alphas) and np.isrealobj(betas) # not implemented yet
    
    # 0th axis: p
    # 1st axis: q
    
    alpha_p = alphas[:, np.newaxis]
    beta_p = betas[:, np.newaxis]
    n_upper_p = n_upper[:, np.newaxis]
    n_lower_p = n_lower[:, np.newaxis]
    
    alpha_q = alphas[np.newaxis, :]
    beta_q = betas[np.newaxis, :]
    n_upper_q = n_upper[np.newaxis, :]
    n_lower_q = n_lower[np.newaxis, :]
    
    corr_mat = alpha_q * beta_p * alpha_q * beta_p * n_upper_p * n_upper_q
    corr_mat += beta_p * beta_q * beta_p * beta_q * n_upper_p * n_lower_q
    corr_mat += alpha_p * alpha_q * alpha_p * alpha_q * n_lower_p * n_upper_q
    corr_mat += alpha_p * beta_q * alpha_p * beta_q * n_lower_p * n_lower_q
    
    diagonal_indices = np.diag_indices_from(corr_mat)
    corr_mat[diagonal_indices] = (
        (alphas ** 2 + betas ** 2) ** 2
    ) * n_upper * n_lower
    
    return corr_mat

# %% [markdown]
# $$\left\langle c_\downarrow^\dagger(p)c_\uparrow^\dagger(q) c_\uparrow(p)c_\downarrow(q)\right\rangle$$

# %%
def corrmat_4_1(alphas: np.ndarray, betas: np.ndarray, n_upper: np.ndarray, n_lower: np.ndarray):
    assert alphas.shape == betas.shape == n_upper.shape == n_lower.shape
    assert np.isrealobj(alphas) and np.isrealobj(betas) # not implemented yet
    
    # 0th axis: p
    # 1st axis: q
    
    alpha_q = alphas[np.newaxis, :]
    beta_q = betas[np.newaxis, :]
    n_upper_q = n_upper[np.newaxis, :]
    n_lower_q = n_lower[np.newaxis, :]
    
    alpha_p = alphas[:, np.newaxis]
    beta_p = betas[:, np.newaxis]
    n_upper_p = n_upper[:, np.newaxis]
    n_lower_p = n_lower[:, np.newaxis]
    
    # off-diagonals
    corr_mat = -alpha_q * beta_p * alpha_p * beta_q * n_upper_q * n_upper_p
    corr_mat += beta_q * beta_p * alpha_q * alpha_p * n_lower_q * n_upper_p
    corr_mat += alpha_q * alpha_p * beta_q * beta_p * n_upper_q * n_lower_p
    corr_mat += -alpha_p * beta_q * alpha_q * beta_p * n_lower_q * n_lower_p
    
    # diagonals
    diagonal_indices = np.diag_indices_from(corr_mat)
    corr_mat[diagonal_indices] = (
        (alphas ** 2 + betas ** 2) ** 2
    ) * n_upper * n_lower
    
    return corr_mat

# %% [markdown]
# $$\braket{c_\uparrow^\dagger(q_x) c_\downarrow^\dagger(p_1) c_\uparrow^\dagger(p_2) c_\uparrow(q_x) c_\uparrow(p_1) c_\downarrow(p_2)}$$

# %%
def corrmat_6_0(alphas: np.ndarray, betas: np.ndarray, n_upper: np.ndarray, n_lower: np.ndarray, qx_slice: slice=slice(None)):
    assert alphas.shape == betas.shape == n_upper.shape == n_lower.shape
    assert np.isrealobj(alphas) and np.isrealobj(betas) # not implemented yet
    
    N = alphas.shape[0]
    
    # 0th axis: qx
    # 1st axis: p1
    # 2nd axis: p2
    
    alpha_qx = alphas[qx_slice, np.newaxis, np.newaxis]
    alpha_p1 = alphas[np.newaxis, :, np.newaxis]
    alpha_p2 = alphas[np.newaxis, np.newaxis, :]
    
    beta_qx = betas[qx_slice, np.newaxis, np.newaxis]
    beta_p1 = betas[np.newaxis, :, np.newaxis]
    beta_p2 = betas[np.newaxis, np.newaxis, :]
    
    n_upper_qx = n_upper[qx_slice, np.newaxis, np.newaxis]
    n_upper_p1 = n_upper[np.newaxis, :, np.newaxis]
    n_upper_p2 = n_upper[np.newaxis, np.newaxis, :]
    
    n_lower_qx = n_lower[qx_slice, np.newaxis, np.newaxis]
    n_lower_p1 = n_lower[np.newaxis, :, np.newaxis]
    n_lower_p2 = n_lower[np.newaxis, np.newaxis, :]
    
    # off-diagonals
    corr_mat = (
        - alpha_p2 * alpha_qx * beta_p1 * alpha_p1 * alpha_qx * beta_p2 * n_upper_p1 * n_upper_p2 * n_upper_qx
        + alpha_qx * beta_p1 * beta_p2 * alpha_p1 * alpha_p2 * alpha_qx * n_upper_p1 * n_lower_p2 * n_upper_qx
        + alpha_p1 * alpha_p2 * alpha_qx * alpha_qx * beta_p1 * beta_p2 * n_lower_p1 * n_upper_p2 * n_upper_qx
        - alpha_p1 * alpha_qx * beta_p2 * alpha_p2 * alpha_qx * beta_p1 * n_lower_p1 * n_lower_p2 * n_upper_qx
        - alpha_p2 * beta_p1 * beta_qx * alpha_p1 * beta_p2 * beta_qx * n_upper_p1 * n_upper_p2 * n_lower_qx
        + beta_p1 * beta_p2 * beta_qx * alpha_p1 * alpha_p2 * beta_qx * n_upper_p1 * n_lower_p2 * n_lower_qx
        + alpha_p1 * alpha_p2 * beta_qx * beta_p1 * beta_p2 * beta_qx * n_lower_p1 * n_upper_p2 * n_lower_qx
        - alpha_p1 * beta_p2 * beta_qx * alpha_p2 * beta_p1 * beta_qx * n_lower_p1 * n_lower_p2 * n_lower_qx
    )
    
    p_indices = np.arange(N, dtype=int)
    sliced_p_indices = p_indices[qx_slice]
    qx_indices = sliced_p_indices - sliced_p_indices[0]
    
    # qx == p1 != p2
    corr_mat[qx_indices, sliced_p_indices, :] = 0
    
    # qx == p2 != p1
    corr_mat[qx_indices, :, sliced_p_indices] = 0
    
    # p1 == p2 != qx
    A = (alpha_p1 ** 2 + beta_p1 ** 2) ** 2
    corr_mat[:, p_indices, p_indices] = np.squeeze(
        A * alpha_qx * alpha_qx * n_upper_p1 * n_lower_p1 * n_upper_qx
        + A * beta_qx * beta_qx * n_upper_p1 * n_lower_p1 * n_lower_qx
    )
    
    # qx == p1 == p2
    corr_mat[qx_indices, sliced_p_indices, sliced_p_indices] = 0
    
    return corr_mat

# %% [markdown]
# $$\braket{c_\uparrow^\dagger(q_x) c_\downarrow^\dagger(p_2) c_\uparrow^\dagger(p_1) c_\uparrow(q_x) c_\uparrow(p_1) c_\downarrow(p_2)}$$

# %%
def corrmat_6_1(alphas: np.ndarray, betas: np.ndarray, n_upper: np.ndarray, n_lower: np.ndarray, qx_slice: slice=slice(None)):
    assert alphas.shape == betas.shape == n_upper.shape == n_lower.shape
    assert np.isrealobj(alphas) and np.isrealobj(betas) # not implemented yet
    
    N = alphas.shape[0]
    
    # 0th axis: qx
    # 1st axis: p1
    # 2nd axis: p2
    
    alpha_qx = alphas[qx_slice, np.newaxis, np.newaxis]
    alpha_p1 = alphas[np.newaxis, :, np.newaxis]
    alpha_p2 = alphas[np.newaxis, np.newaxis, :]
    
    beta_qx = betas[qx_slice, np.newaxis, np.newaxis]
    beta_p1 = betas[np.newaxis, :, np.newaxis]
    beta_p2 = betas[np.newaxis, np.newaxis, :]
    
    n_upper_qx = n_upper[qx_slice, np.newaxis, np.newaxis]
    n_upper_p1 = n_upper[np.newaxis, :, np.newaxis]
    n_upper_p2 = n_upper[np.newaxis, np.newaxis, :]
    
    n_lower_qx = n_lower[qx_slice, np.newaxis, np.newaxis]
    n_lower_p1 = n_lower[np.newaxis, :, np.newaxis]
    n_lower_p2 = n_lower[np.newaxis, np.newaxis, :]
    
    # off-diagonals
    corr_mat = (
        alpha_p1 * alpha_qx * beta_p2 * alpha_p1 * alpha_qx * beta_p2 * n_upper_p1 * n_upper_p2 * n_upper_qx
        + alpha_qx * beta_p1 * beta_p2 * alpha_qx * beta_p1 * beta_p2 * n_lower_p1 * n_upper_p2 * n_upper_qx
        + alpha_p1 * alpha_p2 * alpha_qx * alpha_p1 * alpha_p2 * alpha_qx * n_upper_p1 * n_lower_p2 * n_upper_qx
        + alpha_p2 * alpha_qx * beta_p1 * alpha_p2 * alpha_qx * beta_p1 * n_lower_p1 * n_lower_p2 * n_upper_qx
        + alpha_p1 * beta_p2 * beta_qx * alpha_p1 * beta_p2 * beta_qx * n_upper_p1 * n_upper_p2 * n_lower_qx
        + beta_p1 * beta_p2 * beta_qx * beta_p1 * beta_p2 * beta_qx * n_lower_p1 * n_upper_p2 * n_lower_qx
        + alpha_p1 * alpha_p2 * beta_qx * alpha_p1 * alpha_p2 * beta_qx * n_upper_p1 * n_lower_p2 * n_lower_qx
        + alpha_p2 * beta_p1 * beta_qx * alpha_p2 * beta_p1 * beta_qx * n_lower_p1 * n_lower_p2 * n_lower_qx
    )
    
    p_indices = np.arange(N, dtype=int)
    sliced_p_indices = p_indices[qx_slice]
    qx_indices = sliced_p_indices - sliced_p_indices[0]
    
    # qx == p1 != p2
    corr_mat[qx_indices, sliced_p_indices, :] = 0
    
    # qx == p2 != p1
    A1 = (alpha_qx ** 2 + beta_qx ** 2) ** 2
    corr_mat[qx_indices, :, sliced_p_indices] = np.squeeze(
        A1 * alpha_p1 * alpha_p1 * n_upper_p1 * n_upper_qx * n_lower_qx
        + A1 * beta_p1 * beta_p1 * n_lower_p1 * n_upper_qx * n_lower_qx
    )
    
    # p1 == p2 != qx
    A2 = (alpha_p1 ** 2 + beta_p1 ** 2) ** 2
    corr_mat[:, p_indices, p_indices] = np.squeeze(
        A2 * alpha_qx * alpha_qx * n_upper_p1 * n_lower_p1 * n_upper_qx
        + A2 * beta_qx * beta_qx * n_upper_p1 * n_lower_p1 * n_lower_qx
    )
    
    # qx == p1 == p2
    corr_mat[qx_indices, sliced_p_indices, sliced_p_indices] = 0
    
    return corr_mat

# %% [markdown]
# $$\braket{c_\downarrow^\dagger(q_x) c_\downarrow^\dagger(p_1) c_\uparrow^\dagger(p_2) c_\downarrow(q_x) c_\uparrow(p_1) c_\downarrow(p_2)}$$

# %%
def corrmat_6_2(alphas: np.ndarray, betas: np.ndarray, n_upper: np.ndarray, n_lower: np.ndarray, qx_slice: slice=slice(None)):
    assert alphas.shape == betas.shape == n_upper.shape == n_lower.shape
    assert np.isrealobj(alphas) and np.isrealobj(betas) # not implemented yet
    
    N = alphas.shape[0]
    
    # 0th axis: qx
    # 1st axis: p1
    # 2nd axis: p2
    
    alpha_qx = alphas[:, np.newaxis, np.newaxis]
    alpha_p1 = alphas[np.newaxis, :, np.newaxis]
    alpha_p2 = alphas[np.newaxis, np.newaxis, :]
    
    beta_qx = betas[:, np.newaxis, np.newaxis]
    beta_p1 = betas[np.newaxis, :, np.newaxis]
    beta_p2 = betas[np.newaxis, np.newaxis, :]
    
    n_upper_qx = n_upper[:, np.newaxis, np.newaxis]
    n_upper_p1 = n_upper[np.newaxis, :, np.newaxis]
    n_upper_p2 = n_upper[np.newaxis, np.newaxis, :]
    
    n_lower_qx = n_lower[:, np.newaxis, np.newaxis]
    n_lower_p1 = n_lower[np.newaxis, :, np.newaxis]
    n_lower_p2 = n_lower[np.newaxis, np.newaxis, :]
    
    # off-diagonals
    corr_mat = (
        - alpha_p2 * beta_p1 * beta_qx * alpha_p1 * beta_p2 * beta_qx * n_upper_p1 * n_upper_p2 * n_upper_qx
        + beta_p1 * beta_p2 * beta_qx * alpha_p1 * alpha_p2 * beta_qx * n_upper_p1 * n_lower_p2 * n_upper_qx
        + alpha_p1 * alpha_p2 * beta_qx * beta_p1 * beta_p2 * beta_qx * n_lower_p1 * n_upper_p2 * n_upper_qx
        - alpha_p1 * beta_p2 * beta_qx * alpha_p2 * beta_p1 * beta_qx * n_lower_p1 * n_lower_p2 * n_upper_qx
        - alpha_p2 * alpha_qx * beta_p1 * alpha_p1 * alpha_qx * beta_p2 * n_upper_p1 * n_upper_p2 * n_lower_qx
        + alpha_qx * beta_p1 * beta_p2 * alpha_p1 * alpha_p2 * alpha_qx * n_upper_p1 * n_lower_p2 * n_lower_qx
        + alpha_p1 * alpha_p2 * alpha_qx * alpha_qx * beta_p1 * beta_p2 * n_lower_p1 * n_upper_p2 * n_lower_qx
        - alpha_p1 * alpha_qx * beta_p2 * alpha_p2 * alpha_qx * beta_p1 * n_lower_p1 * n_lower_p2 * n_lower_qx
    )
    
    p_indices = np.arange(N, dtype=int)
    sliced_p_indices = p_indices[qx_slice]
    qx_indices = sliced_p_indices - sliced_p_indices[0]
    
    # qx == p1 != p2
    corr_mat[qx_indices, sliced_p_indices, :] = 0
    
    # qx == p2 != p1
    corr_mat[qx_indices, :, sliced_p_indices] = 0
    
    # p1 == p2 != qx
    A2 = (alpha_p1 ** 2 + beta_p1 ** 2) ** 2
    corr_mat[:, p_indices, p_indices] = np.squeeze(
        A2 * beta_qx * beta_qx * n_upper_p1 * n_lower_p1 * n_upper_qx
        + A2 * alpha_qx * alpha_qx * n_upper_p1 * n_lower_p1 * n_lower_qx
    )
    
    # qx == p1 == p2
    corr_mat[qx_indices, sliced_p_indices, sliced_p_indices] = 0
    
    return corr_mat

# %% [markdown]
# $$\braket{c_\downarrow^\dagger(q_x) c_\downarrow^\dagger(p_2) c_\uparrow^\dagger(p_1) c_\downarrow(q_x) c_\uparrow(p_1) c_\downarrow(p_2)}$$

# %%
def corrmat_6_3(alphas: np.ndarray, betas: np.ndarray, n_upper: np.ndarray, n_lower: np.ndarray, qx_slice: slice=slice(None)):
    assert alphas.shape == betas.shape == n_upper.shape == n_lower.shape
    assert np.isrealobj(alphas) and np.isrealobj(betas) # not implemented yet
    
    N = alphas.shape[0]
    
    # 0th axis: qx
    # 1st axis: p1
    # 2nd axis: p2
    
    alpha_qx = alphas[:, np.newaxis, np.newaxis]
    alpha_p1 = alphas[np.newaxis, :, np.newaxis]
    alpha_p2 = alphas[np.newaxis, np.newaxis, :]
    
    beta_qx = betas[:, np.newaxis, np.newaxis]
    beta_p1 = betas[np.newaxis, :, np.newaxis]
    beta_p2 = betas[np.newaxis, np.newaxis, :]
    
    n_upper_qx = n_upper[:, np.newaxis, np.newaxis]
    n_upper_p1 = n_upper[np.newaxis, :, np.newaxis]
    n_upper_p2 = n_upper[np.newaxis, np.newaxis, :]
    
    n_lower_qx = n_lower[:, np.newaxis, np.newaxis]
    n_lower_p1 = n_lower[np.newaxis, :, np.newaxis]
    n_lower_p2 = n_lower[np.newaxis, np.newaxis, :]
    
    # off-diagonals
    corr_mat = (
        alpha_p1 * beta_p2 * beta_qx * alpha_p1 * beta_p2 * beta_qx * n_upper_p1 * n_upper_p2 * n_upper_qx
        + beta_p1 * beta_p2 * beta_qx * beta_p1 * beta_p2 * beta_qx * n_lower_p1 * n_upper_p2 * n_upper_qx
        + alpha_p1 * alpha_p2 * beta_qx * alpha_p1 * alpha_p2 * beta_qx * n_upper_p1 * n_lower_p2 * n_upper_qx
        + alpha_p2 * beta_p1 * beta_qx * alpha_p2 * beta_p1 * beta_qx * n_lower_p1 * n_lower_p2 * n_upper_qx
        + alpha_p1 * alpha_qx * beta_p2 * alpha_p1 * alpha_qx * beta_p2 * n_upper_p1 * n_upper_p2 * n_lower_qx
        + alpha_qx * beta_p1 * beta_p2 * alpha_qx * beta_p1 * beta_p2 * n_lower_p1 * n_upper_p2 * n_lower_qx
        + alpha_p1 * alpha_p2 * alpha_qx * alpha_p1 * alpha_p2 * alpha_qx * n_upper_p1 * n_lower_p2 * n_lower_qx
        + alpha_p2 * alpha_qx * beta_p1 * alpha_p2 * alpha_qx * beta_p1 * n_lower_p1 * n_lower_p2 * n_lower_qx
    )
    
    p_indices = np.arange(N, dtype=int)
    sliced_p_indices = p_indices[qx_slice]
    qx_indices = sliced_p_indices - sliced_p_indices[0]
    
    # qx == p1 != p2
    A1 = (alpha_qx ** 2 + beta_qx ** 2) ** 2
    corr_mat[qx_indices, sliced_p_indices, :] = np.squeeze(
        A1 * beta_p2 * beta_p2 * n_upper_p2 * n_upper_qx * n_lower_qx
        + A1 * alpha_p2 * alpha_p2 * n_lower_p2 * n_upper_qx * n_lower_qx
    )
    
    # qx == p2 != p1
    corr_mat[qx_indices, :, sliced_p_indices] = 0
    
    # p1 == p2 != qx
    A2 = (alpha_p1 ** 2 + beta_p1 ** 2) ** 2
    corr_mat[:, p_indices, p_indices] = np.squeeze(
        A2 * beta_qx * beta_qx * n_upper_p1 * n_lower_p1 * n_upper_qx
        + A2 * alpha_qx * alpha_qx * n_upper_p1 * n_lower_p1 * n_lower_qx
    )
    
    # qx == p1 == p2
    corr_mat[qx_indices, sliced_p_indices, sliced_p_indices] = 0
    
    return corr_mat

# %%
def initial_loss_lindbladian(temperature_muK, mu):
    temperature = temperature_muK / T_unit
    fermi_level = mu
    zerotemp = temperature < 1e-12

    # --- Calculations ---
    # Energies and Fermi-Dirac distribution
    energies = np.stack([
        ybsoc.e2(points_to_calc, m_Yb, k_r, delta, omega_R, hbar),
        ybsoc.e1(points_to_calc, m_Yb, k_r, delta, omega_R, hbar)
    ])
    
    if zerotemp:
        below_fermi = energies <= fermi_level
        fermi_dirac = below_fermi.astype(float)
    else:
        beta = 1 / temperature
        fermi_dirac = 1 / (np.exp(beta * (energies - mu)) + 1)

    # Mixing angles
    thetas = ybsoc.theta(points_to_calc, m_Yb, k_r, delta, omega_R, hbar)
    alphas = np.cos(thetas)
    betas = np.sin(thetas)

    # Initial populations
    n_lowers = fermi_dirac[0, :]
    n_uppers = fermi_dirac[1, :]
    initial_up = (alphas ** 2) * n_uppers + (betas ** 2) * n_lowers
    initial_down = (betas ** 2) * n_uppers + (alphas ** 2) * n_lowers
    initial_total = initial_up + initial_down

    # Loss rate calculation
    # 0th axis: q_x, 1st axis: p
    corr_mat = corrmat_4_0(alphas, betas, n_uppers, n_lowers).T + corrmat_4_1(alphas, betas, n_uppers, n_lowers)
    
    loss_rate_up = (gamma / (L * hbar)) * np.sum(corr_mat, axis=1)
    loss_rate_down = (gamma / (L * hbar)) * np.sum(corr_mat.T, axis=1)
    loss_rate_total = loss_rate_up + loss_rate_down

    # Loss fraction calculation
    def calc_frac(num, den, eps=1e-20):
        return np.where(np.abs(den) > eps, num / den, 0.0)

    loss_fraction_up = calc_frac(loss_rate_up, initial_up)
    loss_fraction_down = calc_frac(loss_rate_down, initial_down)
    loss_fraction_total = calc_frac(loss_rate_total, initial_total)
    
    # --- Data for Fermi Sea Scatter Plot ---
    if zerotemp:
        q_fermi_sea = np.concatenate([
            points_to_calc[below_fermi[0]],
            points_to_calc[below_fermi[1]]
        ])
        E_fermi_sea = np.concatenate([
            energies[0][below_fermi[0]],
            energies[1][below_fermi[1]]
        ])
        # Adding small random jitter for visualization
        q_scatter = q_fermi_sea + 0.1 * np.random.uniform(-1, 1, size=q_fermi_sea.shape)
        e_scatter = E_fermi_sea + 0.1 * np.random.uniform(-1, 1, size=E_fermi_sea.shape) # Reduced jitter
    else:
        rands = np.random.uniform(0, 1, size=fermi_dirac.shape)
        selected = rands <= fermi_dirac
        q_scatter = np.concatenate([
            points_to_calc[selected[0]],
            points_to_calc[selected[1]]
        ])
        e_scatter = np.concatenate([
            energies[0][selected[0]],
            energies[1][selected[1]]
        ])

    # --- Prepare canonical arrays for plotting ---
    size = initial_up.shape[0]
    size_canon = size + 2 * m
    
    initial_up_canon = np.zeros((size_canon))
    initial_up_canon[:-2 * m] = initial_up
    initial_down_canon = np.zeros((size_canon))
    initial_down_canon[2 * m:] = initial_down
    initial_total_canon = initial_up_canon + initial_down_canon

    loss_rate_up_canon = np.zeros((size_canon))
    loss_rate_up_canon[:-2 * m] = loss_rate_up
    loss_rate_down_canon = np.zeros((size_canon))
    loss_rate_down_canon[2 * m:] = loss_rate_down
    loss_rate_total_canon = loss_rate_up_canon + loss_rate_down_canon

    loss_fraction_up_canon = calc_frac(loss_rate_up_canon, initial_up_canon)
    loss_fraction_down_canon = calc_frac(loss_rate_down_canon, initial_down_canon)
    loss_fraction_total_canon = calc_frac(loss_rate_total_canon, initial_total_canon)

    # Return all results in a dictionary
    return {
        "q_scatter": q_scatter, "e_scatter": e_scatter,
        "initial_up": initial_up, "initial_down": initial_down, "initial_total": initial_total,
        "loss_rate_up": loss_rate_up, "loss_rate_down": loss_rate_down, "loss_rate_total": loss_rate_total,
        "loss_fraction_up": loss_fraction_up, "loss_fraction_down": loss_fraction_down, "loss_fraction_total": loss_fraction_total,
        "initial_up_canon": initial_up_canon, "initial_down_canon": initial_down_canon, "initial_total_canon": initial_total_canon,
        "loss_rate_up_canon": loss_rate_up_canon, "loss_rate_down_canon": loss_rate_down_canon, "loss_rate_total_canon": loss_rate_total_canon,
        "loss_fraction_up_canon": loss_fraction_up_canon, "loss_fraction_down_canon": loss_fraction_down_canon, "loss_fraction_total_canon": loss_fraction_total_canon,
    }

# %% [markdown]
# $$
# \begin{align}
# 	\frac{d}{dt}\langle n_\uparrow(q_x)\rangle
# 	=&-\frac{\gamma}{V\hbar}\operatorname{Re}\sum_p\langle c_\downarrow^\dagger(p)c_\uparrow^\dagger(q_x)c_\uparrow(q_x)c_\downarrow(p)\rangle\\
# 	&-\frac{\gamma}{V\hbar}\operatorname{Re}\sum_p\langle c_\downarrow^\dagger(p)c_\uparrow^\dagger(q_x)c_\uparrow(p)c_\downarrow(q_x)\rangle\\
# 	&+\frac{\gamma}{V\hbar}\braket{n_\uparrow(q_x)n_\downarrow(q_x)} \\
# 	&-\frac{\gamma}{V\hbar}\operatorname{Re}\sum_{p_1, p_2}\braket{c_\uparrow^\dagger(q_x) c_\downarrow^\dagger(p_1) c_\uparrow^\dagger(p_2) c_\uparrow(q_x) c_\uparrow(p_1) c_\downarrow(p_2)}\\
# 	&-\frac{\gamma}{V\hbar}\operatorname{Re}\sum_{p_1, p_2}\braket{c_\uparrow^\dagger(q_x) c_\downarrow^\dagger(p_2) c_\uparrow^\dagger(p_1) c_\uparrow(q_x) c_\uparrow(p_1) c_\downarrow(p_2)}
# \end{align}
# $$

# %%
def initial_loss_non_hermitian(temperature_muK, mu):
    temperature = temperature_muK / T_unit
    fermi_level = mu
    zerotemp = temperature < 1e-12

    # --- Calculations ---
    # Energies and Fermi-Dirac distribution
    energies = np.stack([
        ybsoc.e2(points_to_calc, m_Yb, k_r, delta, omega_R, hbar),
        ybsoc.e1(points_to_calc, m_Yb, k_r, delta, omega_R, hbar)
    ])
    
    if zerotemp:
        below_fermi = energies <= fermi_level
        fermi_dirac = below_fermi.astype(float)
    else:
        beta = 1 / temperature
        fermi_dirac = 1 / (np.exp(beta * (energies - mu)) + 1)

    # Mixing angles
    thetas = ybsoc.theta(points_to_calc, m_Yb, k_r, delta, omega_R, hbar)
    alphas = np.cos(thetas)
    betas = np.sin(thetas)

    # Initial populations
    n_lowers = fermi_dirac[0, :]
    n_uppers = fermi_dirac[1, :]
    initial_up = (alphas ** 2) * n_uppers + (betas ** 2) * n_lowers
    initial_down = (betas ** 2) * n_uppers + (alphas ** 2) * n_lowers
    initial_total = initial_up + initial_down

    # Loss rate calculation
    # 0th axis: q_x, 1st axis: p
    loss_rate_up = (gamma / (L * hbar)) * (
        + np.sum(corrmat_4_0(alphas, betas, n_uppers, n_lowers), axis=0)
        + np.sum(corrmat_4_1(alphas, betas, n_uppers, n_lowers), axis=0)
        - n_uppers * n_lowers
        + np.sum(corrmat_6_0(alphas, betas, n_uppers, n_lowers), axis=(1, 2))
        + np.sum(corrmat_6_1(alphas, betas, n_uppers, n_lowers), axis=(1, 2))
    )
    
    loss_rate_down = (gamma / (L * hbar)) * (
        + np.sum(corrmat_4_1(alphas, betas, n_uppers, n_lowers), axis=1)
        + np.sum(corrmat_4_0(alphas, betas, n_uppers, n_lowers), axis=1)
        - n_uppers * n_lowers
        + np.sum(corrmat_6_2(alphas, betas, n_uppers, n_lowers), axis=(1, 2))
        + np.sum(corrmat_6_3(alphas, betas, n_uppers, n_lowers), axis=(1, 2))
    )
    
    loss_rate_total = loss_rate_up + loss_rate_down

    # Loss fraction calculation
    def calc_frac(num, den, eps=1e-20):
        return np.where(np.abs(den) > eps, num / den, 0.0)

    loss_fraction_up = calc_frac(loss_rate_up, initial_up)
    loss_fraction_down = calc_frac(loss_rate_down, initial_down)
    loss_fraction_total = calc_frac(loss_rate_total, initial_total)
    
    # --- Data for Fermi Sea Scatter Plot ---
    if zerotemp:
        q_fermi_sea = np.concatenate([
            points_to_calc[below_fermi[0]],
            points_to_calc[below_fermi[1]]
        ])
        E_fermi_sea = np.concatenate([
            energies[0][below_fermi[0]],
            energies[1][below_fermi[1]]
        ])
        # Adding small random jitter for visualization
        q_scatter = q_fermi_sea + 0.1 * np.random.uniform(-1, 1, size=q_fermi_sea.shape)
        e_scatter = E_fermi_sea + 0.1 * np.random.uniform(-1, 1, size=E_fermi_sea.shape) # Reduced jitter
    else:
        rands = np.random.uniform(0, 1, size=fermi_dirac.shape)
        selected = rands <= fermi_dirac
        q_scatter = np.concatenate([
            points_to_calc[selected[0]],
            points_to_calc[selected[1]]
        ])
        e_scatter = np.concatenate([
            energies[0][selected[0]],
            energies[1][selected[1]]
        ])

    # --- Prepare canonical arrays for plotting ---
    size = initial_up.shape[0]
    size_canon = size + 2 * m
    
    initial_up_canon = np.zeros((size_canon))
    initial_up_canon[:-2 * m] = initial_up
    initial_down_canon = np.zeros((size_canon))
    initial_down_canon[2 * m:] = initial_down
    initial_total_canon = initial_up_canon + initial_down_canon

    loss_rate_up_canon = np.zeros((size_canon))
    loss_rate_up_canon[:-2 * m] = loss_rate_up
    loss_rate_down_canon = np.zeros((size_canon))
    loss_rate_down_canon[2 * m:] = loss_rate_down
    loss_rate_total_canon = loss_rate_up_canon + loss_rate_down_canon

    loss_fraction_up_canon = calc_frac(loss_rate_up_canon, initial_up_canon)
    loss_fraction_down_canon = calc_frac(loss_rate_down_canon, initial_down_canon)
    loss_fraction_total_canon = calc_frac(loss_rate_total_canon, initial_total_canon)

    # Return all results in a dictionary
    return {
        "q_scatter": q_scatter, "e_scatter": e_scatter,
        "initial_up": initial_up, "initial_down": initial_down, "initial_total": initial_total,
        "loss_rate_up": loss_rate_up, "loss_rate_down": loss_rate_down, "loss_rate_total": loss_rate_total,
        "loss_fraction_up": loss_fraction_up, "loss_fraction_down": loss_fraction_down, "loss_fraction_total": loss_fraction_total,
        "initial_up_canon": initial_up_canon, "initial_down_canon": initial_down_canon, "initial_total_canon": initial_total_canon,
        "loss_rate_up_canon": loss_rate_up_canon, "loss_rate_down_canon": loss_rate_down_canon, "loss_rate_total_canon": loss_rate_total_canon,
        "loss_fraction_up_canon": loss_fraction_up_canon, "loss_fraction_down_canon": loss_fraction_down_canon, "loss_fraction_total_canon": loss_fraction_total_canon,
    }

# %%
temperatures_to_sim = [0.0, 0.01, 0.02, 0.04, 0.08]  # μK
mus_to_sim = [2.4, 2.6, 2.8, 3.0, 3.2]        # Er
all_results = {}
for mu in mus_to_sim:
    for T in temperatures_to_sim:
        print(f"Calculating for: T={T}μK, μ={mu}")
        all_results[(T, mu)] = initial_loss_non_hermitian(temperature_muK=T, mu=mu)
print("All calculations complete.")
# Out:
# Calculating for: T=0.0μK, μ=2.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 7
#       5     for T in temperatures_to_sim:
#       6         print(f"Calculating for: T={T}μK, μ={mu}")
# ----> 7         all_results[(T, mu)] = initial_loss_non_hermitian(temperature_muK=T, mu=mu)
#       8 print("All calculations complete.")
#
# Cell In[12], line 62, in initial_loss_non_hermitian(temperature_muK, mu)
#      58     idx_end = min(idx_start + batch_size, n_points)
#      59     qx_slice = slice(idx_start, idx_end)
#      60     loss_rate_down[qx_slice] += (gamma / (L * hbar)) * (
#      61         np.sum(corrmat_6_2(alphas, betas, n_uppers, n_lowers, qx_slice=qx_slice), axis=(1, 2))
# ---> 62         + np.sum(corrmat_6_3(alphas, betas, n_uppers, n_lowers, qx_slice=qx_slice), axis=(1, 2))
#      63     )
#      66 loss_rate_total = loss_rate_up + loss_rate_down
# ...

# %%
nrows, ncols = len(mus_to_sim), len(temperatures_to_sim)
# --- Plot 1: 에너지 스펙트럼 및 페르미 바다 ---

fig, axes = plt.subplots(nrows, ncols, figsize=(3 * ncols, 3 * nrows), sharex=True, sharey=True)
fig.suptitle("Dispersion relation and Occupied States", fontsize=16, y=0.95)
fig.subplots_adjust(wspace=0, hspace=0, right=0.88) # 오른쪽 여백 조정

# 밴드 구조 배경 (LineCollection) 생성
qs_dense = np.linspace(q_left, q_right, 1401)
E_upper_dense = ybsoc.e1(qs_dense, m_Yb, k_r, delta, omega_R, hbar)
E_lower_dense = ybsoc.e2(qs_dense, m_Yb, k_r, delta, omega_R, hbar)
thetas_dense = ybsoc.theta(qs_dense, delta=delta, omega_R=omega_R, k_r=k_r, m_Yb=m_Yb)
custom_cmap = LinearSegmentedColormap.from_list("custom_cmap", ['tomato', 'cornflowerblue'])
norm = Normalize(vmin=0.0, vmax=1.0)

# 선분 데이터 생성
points_up = np.array([qs_dense, E_upper_dense]).T.reshape(-1, 1, 2)
segments_up = np.concatenate([points_up[:-1], points_up[1:]], axis=1)

points_down = np.array([qs_dense, E_lower_dense]).T.reshape(-1, 1, 2)
segments_down = np.concatenate([points_down[:-1], points_down[1:]], axis=1)

# LineCollection 객체를 미리 한 번만 생성
lc_up = LineCollection(segments_up, cmap=custom_cmap, norm=norm, lw=1.5)
lc_up.set_array(np.abs(np.sin(thetas_dense))**2)
lc_down = LineCollection(segments_down, cmap=custom_cmap, norm=norm, lw=1.5)
lc_down.set_array(np.abs(np.cos(thetas_dense))**2)


for i, mu in enumerate(mus_to_sim):
    for j, T in enumerate(temperatures_to_sim):
        ax = axes[i, j]
        data = all_results[(T, mu)]

        # 미리 생성한 LineCollection 객체를 복사하여 추가
        ax.add_collection(copy.copy(lc_up))
        ax.add_collection(copy.copy(lc_down))
        
        ax.axhline(y=mu, color='k', ls='--', lw=1)
        ax.scatter(data['q_scatter'], data['e_scatter'], color='blueviolet', s=3, alpha=0.40, label='occupied states')
        
        # 축 레이블 및 타이틀 설정
        if i < nrows - 1: ax.tick_params(labelbottom=False)
        if j > 0: ax.tick_params(labelleft=False)
        if i == 0: ax.set_title(f"T = {T} μK", fontsize=10)
        if j == ncols - 1: ax.secondary_yaxis("right").set_ylabel(f"$\\mu = {mu} E_r$", rotation=270, labelpad=15)
        if j == 0: ax.set_ylabel("$E/E_r$")
        if i == nrows - 1: ax.set_xlabel("$q_x/k_r$")
        ax.set_xlim(-6, 4)
        ax.set_ylim(-10, 50)
        ax.grid(True, alpha=0.3, lw=0.5)

# # 공통 Colorbar 설정
# cbar_ax = fig.add_axes([0.9, 0.15, 0.02, 0.7])
# sm = ScalarMappable(cmap=custom_cmap, norm=norm)
# cbar = fig.colorbar(sm, cax=cbar_ax, ticks=[0, 1])
# cbar.set_ticklabels([r'$m_F=5/2$', r'$m_F=3/2$'])
# cbar.ax.invert_yaxis()
# cbar.set_label(r'Mixing Ratio')

handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='outside upper right')

plt.show()

# %%
fig, axes = plt.subplots(nrows, ncols, figsize=(3 * ncols, 3 * nrows), sharex=True, sharey=True)
fig.suptitle("Initial Population", fontsize=16, y=0.95)
fig.subplots_adjust(wspace=0, hspace=0)
for i, mu in enumerate(mus_to_sim):
    for j, T in enumerate(temperatures_to_sim):
        ax = axes[i, j]
        data = all_results[(T, mu)]
        ax.plot(points_to_calc, data['initial_up'], color='tomato', lw=1.5, label="$\\uparrow$")
        ax.plot(points_to_calc, data['initial_down'], color='cornflowerblue', lw=1.5, label="$\\downarrow$")
        ax.plot(points_to_calc, data['initial_total'], color='purple', lw=1.5, ls='--', label="Total")
        if i < nrows - 1: ax.tick_params(labelbottom=False)
        if j > 0: ax.tick_params(labelleft=False)
        if i == 0: ax.set_title(f"T = {T} μK", fontsize=10)
        if j == ncols - 1: ax.secondary_yaxis("right").set_ylabel(f"$\\mu = {mu} E_r$", rotation=270, labelpad=15)
        if j == 0: ax.set_ylabel("$\\langle n(q_x)\\rangle$")
        if i == nrows - 1: ax.set_xlabel("$q_x/k_r$")
        ax.grid(True, alpha=0.3, lw=0.5)
handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='outside upper right')
plt.show()

# %%
# fig, axes = plt.subplots(nrows, ncols, figsize=(3 * ncols, 3 * nrows), sharex=True, sharey=True)
# fig.suptitle("Loss Rate", fontsize=16, y=0.95)
# fig.subplots_adjust(wspace=0, hspace=0)
# for i, mu in enumerate(mus_to_sim):
#     for j, T in enumerate(temperatures_to_sim):
#         ax = axes[i, j]
#         data = all_results[(T, mu)]
#         ax.plot(points_to_calc, data['loss_rate_up'], color='tomato', lw=1.5, label="$\\uparrow$")
#         ax.plot(points_to_calc, data['loss_rate_down'], color='cornflowerblue', lw=1.5, label="$\\downarrow$")
#         ax.plot(points_to_calc, data['loss_rate_total'], color='purple', lw=1.5, ls='--', label="Total")
#         if i < nrows - 1: ax.tick_params(labelbottom=False)
#         if j > 0: ax.tick_params(labelleft=False)
#         if i == 0: ax.set_title(f"T = {T} μK", fontsize=10)
#         if j == ncols - 1: ax.secondary_yaxis("right").set_ylabel(f"$\\mu = {mu} E_r$", rotation=270, labelpad=15)
#         if j == 0: ax.set_ylabel("$-d\\langle n(q_x)\\rangle/dt$")
#         if i == nrows - 1: ax.set_xlabel("$q_x/k_r$")
#         ax.grid(True, alpha=0.3, lw=0.5)
# handles, labels = axes[0,0].get_legend_handles_labels()
# fig.legend(handles, labels, loc='outside upper right')
# plt.show()

# %%
# fig, axes = plt.subplots(nrows, ncols, figsize=(3 * ncols, 3 * nrows), sharex=True, sharey=True)
# fig.suptitle("Loss Fraction", fontsize=16, y=0.95)
# fig.subplots_adjust(wspace=0, hspace=0)
# for i, mu in enumerate(mus_to_sim):
#     for j, T in enumerate(temperatures_to_sim):
#         ax = axes[i, j]
#         data = all_results[(T, mu)]
#         ax.plot(points_to_calc, data['loss_fraction_up'], color='tomato', lw=1.5, label="$\\uparrow$")
#         ax.plot(points_to_calc, data['loss_fraction_down'], color='cornflowerblue', lw=1.5, label="$\\downarrow$")
#         ax.plot(points_to_calc, data['loss_fraction_total'], color='purple', lw=1.5, ls='--', label="Total")
#         if i < nrows - 1: ax.tick_params(labelbottom=False)
#         if j > 0: ax.tick_params(labelleft=False)
#         if i == 0: ax.set_title(f"T = {T} μK", fontsize=10)
#         if j == ncols - 1: ax.secondary_yaxis("right").set_ylabel(f"$\\mu = {mu} E_r$", rotation=270, labelpad=15)
#         if j == 0: ax.set_ylabel("$-(1/n_0)(dn/dt)$")
#         if i == nrows - 1: ax.set_xlabel("$q_x/k_r$")
#         ax.axhline(y=0, color='k', lw=1)
#         ax.set_ylim(-0.05, 0.5); ax.set_xlim(-5, 5)
#         ax.grid(True, alpha=0.3, lw=0.5)
# handles, labels = axes[0,0].get_legend_handles_labels()
# fig.legend(handles, labels, loc='outside upper right')
# plt.show()

# %%
fig, axes = plt.subplots(nrows, ncols, figsize=(3 * ncols, 3 * nrows), sharex=True, sharey=True)
fig.suptitle("Initial Population", fontsize=16, y=0.95)
fig.subplots_adjust(wspace=0, hspace=0)
for i, mu in enumerate(mus_to_sim):
    for j, T in enumerate(temperatures_to_sim):
        ax = axes[i, j]
        data = all_results[(T, mu)]
        ax.plot(points_to_calc_canon, data['initial_up_canon'], color='tomato', lw=1.5, label="$\\uparrow$")
        ax.plot(points_to_calc_canon, data['initial_down_canon'], color='cornflowerblue', lw=1.5, label="$\\downarrow$")
        ax.plot(points_to_calc_canon, data['initial_total_canon'], color='purple', lw=1.5, ls='--', label="Total")
        if i < nrows - 1: ax.tick_params(labelbottom=False)
        if j > 0: ax.tick_params(labelleft=False)
        if i == 0: ax.set_title(f"T = {T} μK", fontsize=10)
        if j == ncols - 1: ax.secondary_yaxis("right").set_ylabel(f"$\\mu = {mu} E_r$", rotation=270, labelpad=15)
        if j == 0: ax.set_ylabel("$\\langle n(k_x)\\rangle$")
        if i == nrows - 1: ax.set_xlabel("$k_x/k_r$")
        ax.grid(True, alpha=0.3, lw=0.5)
handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='outside upper right')
plt.show()

# %%
fig, axes = plt.subplots(nrows, ncols, figsize=(3 * ncols, 3 * nrows), sharex=True, sharey=True)
fig.suptitle("Loss Rate", fontsize=16, y=0.95)
fig.subplots_adjust(wspace=0, hspace=0)
for i, mu in enumerate(mus_to_sim):
    for j, T in enumerate(temperatures_to_sim):
        ax = axes[i, j]
        data = all_results[(T, mu)]
        ax.plot(points_to_calc_canon, data['loss_rate_up_canon'], color='tomato', lw=1.5, label="$\\uparrow$")
        ax.plot(points_to_calc_canon, data['loss_rate_down_canon'], color='cornflowerblue', lw=1.5, label="$\\downarrow$")
        ax.plot(points_to_calc_canon, data['loss_rate_total_canon'], color='purple', lw=1.5, ls='--', label="Total")
        if i < nrows - 1: ax.tick_params(labelbottom=False)
        if j > 0: ax.tick_params(labelleft=False)
        if i == 0: ax.set_title(f"T = {T} μK", fontsize=10)
        if j == ncols - 1: ax.secondary_yaxis("right").set_ylabel(f"$\\mu = {mu} E_r$", rotation=270, labelpad=15)
        if j == 0: ax.set_ylabel("$-d\\langle n(k_x)\\rangle/dt$")
        if i == nrows - 1: ax.set_xlabel("$k_x/k_r$")
        ax.grid(True, alpha=0.3, lw=0.5)
handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='outside upper right')
plt.show()

# %%
from scipy.signal import find_peaks

fig, axes = plt.subplots(nrows, ncols, figsize=(3 * ncols, 3 * nrows), sharex=True, sharey=True)
fig.suptitle("Loss Fraction", fontsize=16, y=0.95)
fig.subplots_adjust(wspace=0, hspace=0)
for i, mu in enumerate(mus_to_sim):
    for j, T in enumerate(temperatures_to_sim):
        ax = axes[i, j]
        data = all_results[(T, mu)]
        ax.plot(points_to_calc_canon, data['loss_fraction_up_canon'], color='tomato', lw=1.5, label="$\\uparrow$")
        ax.plot(points_to_calc_canon, data['loss_fraction_down_canon'], color='cornflowerblue', lw=1.5, label="$\\downarrow$")
        ax.plot(points_to_calc_canon, data['loss_fraction_total_canon'], color='purple', lw=1.5, ls='--', label="Total")
        
        total_loss = data['loss_fraction_total_canon']
        # peak_indices, _ = find_peaks(total_loss)
        # x_peaks = points_to_calc_canon[peak_indices]
        # y_peaks = total_loss[peak_indices]
        # ax.scatter(x_peaks, y_peaks, color='red', marker='o', s=20, zorder=5) 


        if i < nrows - 1: ax.tick_params(labelbottom=False)
        if j > 0: ax.tick_params(labelleft=False)
        if i == 0: ax.set_title(f"T = {T} μK", fontsize=10)
        if j == ncols - 1: ax.secondary_yaxis("right").set_ylabel(f"$\\mu = {mu} E_r$", rotation=270, labelpad=15)
        if j == 0: ax.set_ylabel("$-(1/n_0)(dn/dt)$")
        if i == nrows - 1: ax.set_xlabel("$k_x/k_r$")
        ax.axhline(y=0, color='k', lw=1)
        ax.axvline(x=1, color='k', lw=1)
        
        # ax.set_ylim(-0.05, 0.5)
        ax.set_xlim(-1, 3)
        ax.grid(True, alpha=0.3, lw=0.5)
handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='outside upper right')
plt.show()
